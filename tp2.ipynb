# %% [markdown]
# # TRABAJO PRACTICO NRO. 2
# ## ANALISIS DE COMPARACION DE INDICADORES POR PAISES.

# %% [markdown]
# Gente querida,
#
# Al final de la clase pasada, les presenté nuestro próximo desafío: un DataSet enorme con decenas de indicadores de calidad de vida tabulados en los últimos 60 años por la ONU para todos los países del mundo!! Hay allí como para hacer dulce... un conjunto de datos súper interesante! Pero además, propone ciertos desafíos. A continuación van algunas consideraciones:
#
#
#
# Material a trabajar para nuestra próximo encuentro
#
# El DataSet completo pueden descargarlo de este link:
# https://mega.nz/file/gx00xSpb#IwxEcT72T-eUhMGZARN7lyiG-zOcwBECE3rz3Mw_YT8
#
# Como verán, tienen información distribuida en diferentes archivos .CSV: Sólo uno contiene los datos a analizar (HNP_StatsData.csv) y el resto contienen información que nos permite entender lo que leemos allí... Hay referencias sobre los indicadores tabulados, su significado y su manera de cálculo; referencias sobre los países y qué datos se disponen para cada país, etc... Deberán mirar cada tabla para entender su estructura y la información que nos aporta.
#
# Puntualmente, para este DataSet, tengo la intención que puedan poner en práctica las herramientas específicas de pandas para poder manipular datos en columnas, ya que habitualmente los habríamos encontrado en filas con la clave: {"Country Code","Indicator Code","Year"}
#
#
#
# Un Tip para tener presente: vean el método .melt de pandas... les permitirá acomodar los datos, trasponiendo "sólo las columnas necesarias"!! Pueden dejar la clave que identifica al país e indicador que nos interesa, y agregar una columna para el año y otra para el valor registrado en dicha posición!
#
#
#
# Tener en cuenta la siguiente pauta para el trabajo:
#
# 1. Considerar los siguientes índices ** :
#
# * SP.DYN.CBRT.IN
# * SP.DYN.LE00.IN
# * HD.HCI.OVRL
# * NY.GNP.PCAP.CD
#
# Averiguar a qué se refiere cada uno de ellos...
#
# 2. Quedarnos sólo con las filas del DataSet principal que contienen los datos indicados.
#
# 3. Establecer una “comparativa gráfica” de Argentina respecto de otros países para estos indicadores… Habrá que bucear un poco en los datos para ver qué y cómo pueden comparar. También deberemos elegir contra qué países comparar en función de lo que nos interese observar: deberá cada uno justificar su elección.
#
# 4. Procurar establecer una suerte de correlación “visual” entre ellos. Por ejemplo, me parece que puede ser interesante revisar los primeros dos respecto del tercero (Tasa de Natalidad y Mortalidad vs Índice de Capital Humano); o también entre el tercero y el cuarto (Índice de Capital Humano vs. Ingreso Bruto per Cápita).
#
#
#
# Finalmente, a lo anterior agregar un último desafío: puede ser de difícil lectura una gráfica que incluya tantas columnas de datos… estamos hablando de casi 60! Una lectura visualmente más abarcable puede lograrse si recortamos en periodos más grandes, como por ejemplo, por lustros (agrupando o tomando información cada 5 años). Ya tienen las herramientas para generar esto también!
#
# Deseándoles una linda semana, los saludo con un abrazo!!

# %% [markdown]
# ## Empezamos.
#
# Lo primero que hacemos es cargar las librerias con las que vamos a trabajar.

# %%
import numpy as np 
import pandas as pd 
import plotly.express as px
from plotly.offline import plot 
import pycountry

# %% [markdown]
# #### Cargamos el el archivo con los datos.

# %%
df = pd.read_csv("data/HNP_StatsData.csv")

# %% [markdown]
# Elimino la ultima columna que no vamos a utilizar.

# %%
df = df.drop([r"Unnamed: 65"], axis = 1)

# %% [markdown]
# Para poder trabajar mejor con el dataframe decidi cambiarle el nombre a las columnas por los siguientes nombres.
# * Country Name: pais
# * Country Code: codigo_pais
# * Indicator Name : indicador
# * Indicator Code : codigo_indicador

# %%
df = df.rename(columns= {'Country Name': 'pais', 'Country Code': 'codigo_pais', 
                         'Indicator Name': 'indicador', 'Indicator Code':'codigo_indicador'})

# %% [markdown]
# Creo un nuevo data frame donde van a estar los paises con los que vamos a trabajar y los indicadores que vamos a usar.

# %%
df1 = pd.DataFrame()
df1 = df[df["codigo_pais"].isin(['ARG','CHL','BRA','FRA','NZL','CAN'])]
df1 = df1[df1["codigo_indicador"].isin(["SP.DYN.CBRT.IN","SP.DYN.LE00.IN","HD.HCI.OVRL","NY.GNP.PCAP.CD"])]

# %%
df1
# Out:
#               pais codigo_pais                                   indicador  \
# 20401    Argentina         ARG        Birth rate, crude (per 1,000 people)
# 20453    Argentina         ARG  GNI per capita, Atlas method (current US$)
# 20455    Argentina         ARG       Human capital index (HCI) (scale 0-1)
# 20483    Argentina         ARG     Life expectancy at birth, total (years)
# 28286       Brazil         BRA        Birth rate, crude (per 1,000 people)
# 28338       Brazil         BRA  GNI per capita, Atlas method (current US$)
# 28340       Brazil         BRA       Human capital index (HCI) (scale 0-1)
# 28368       Brazil         BRA     Life expectancy at birth, total (years)
# 32021       Canada         CAN        Birth rate, crude (per 1,000 people)
# 32073       Canada         CAN  GNI per capita, Atlas method (current US$)
# 32075       Canada         CAN       Human capital index (HCI) (scale 0-1)
# 32103       Canada         CAN     Life expectancy at birth, total (years)
# 34096        Chile         CHL        Birth rate, crude (per 1,000 people)
# 34148        Chile         CHL  GNI per capita, Atlas method (current US$)
# 34150        Chile         CHL       Human capital index (HCI) (scale 0-1)
# 34178        Chile         CHL     Life expectancy at birth, total (years)
# 45716       France         FRA        Birth rate, crude (per 1,000 people)
# 45768       France         FRA  GNI per capita, Atlas method (current US$)
# 45770       France         FRA       Human capital index (HCI) (scale 0-1)
# 45798       France         FRA     Life expectancy at birth, total (years)
# 76011  New Zealand         NZL        Birth rate, crude (per 1,000 people)
# 76063  New Zealand         NZL  GNI per capita, Atlas method (current US$)
# 76065  New Zealand         NZL       Human capital index (HCI) (scale 0-1)
# 76093  New Zealand         NZL     Life expectancy at birth, total (years)
#
#       codigo_indicador       1960       1961         1962         1963  \
# 20401   SP.DYN.CBRT.IN  23.775000  23.569000    23.372000    23.191000
# 20453   NY.GNP.PCAP.CD        NaN        NaN          NaN          NaN
# 20455      HD.HCI.OVRL        NaN        NaN          NaN          NaN
# 20483   SP.DYN.LE00.IN  65.055000  65.176000    65.269000    65.348000
# 28286   SP.DYN.CBRT.IN  42.280000  41.932000    41.481000    40.914000
# 28338   NY.GNP.PCAP.CD        NaN        NaN          NaN          NaN
# 28340      HD.HCI.OVRL        NaN        NaN          NaN          NaN
# 28368   SP.DYN.LE00.IN  54.143000  54.634000    55.130000    55.627000
# 32021   SP.DYN.CBRT.IN  26.700000  26.000000    25.200000    24.600000
# 32073   NY.GNP.PCAP.CD        NaN        NaN          NaN          NaN
# 32075      HD.HCI.OVRL        NaN        NaN          NaN          NaN
# 32103   SP.DYN.LE00.IN  71.133171  71.346098    71.367073    71.380732
# 34096   SP.DYN.CBRT.IN  35.556000  35.108000    34.588000    33.994000
# 34148   NY.GNP.PCAP.CD        NaN        NaN   580.000000   630.000000
# 34150      HD.HCI.OVRL        NaN        NaN          NaN          NaN
#
# 45770           NaN           NaN           NaN           NaN      0.765000
# 45798     82.219512     82.719512     82.321951     82.573171     82.575610
# 76011     13.200000     12.680000     13.270000     12.650000     12.430000
# 76063  39910.000000  41630.000000  40560.000000  39390.000000  38170.000000
# 76065           NaN           NaN           NaN           NaN      0.767000
# 76093     81.407317     81.404878     81.456829     81.612439     81.658537
#
#                2018     2019      2020
# 20401     17.021000      NaN       NaN
# 20453  12390.000000  11200.0       NaN
# 20455      0.617367      NaN  0.602145
# 20483     76.520000      NaN       NaN
# 28286     13.924000      NaN       NaN
# 28338   9080.000000   9130.0       NaN
# 28340      0.545724      NaN  0.551498
# 28368     75.672000      NaN       NaN
# 32021     10.100000      NaN       NaN
# 32073  45000.000000  46370.0       NaN
# 32075      0.800090      NaN  0.797520
# 32103     81.948780      NaN       NaN
# 34096     12.428000      NaN       NaN
# 34148  14620.000000  15010.0       NaN
# 34150      0.665265      NaN  0.651604
# 34178     80.042000      NaN       NaN
# 45716     11.300000      NaN       NaN
# 45768  41080.000000  42400.0       NaN
# 45770      0.755960      NaN  0.762737
# 45798     82.724390      NaN       NaN
# 76011     11.980000      NaN       NaN
# 76063  41100.000000  42670.0       NaN
# 76065      0.771214      NaN  0.775932
# 76093     81.858537      NaN       NaN
#
# [24 rows x 65 columns]

# %%
#df1.info()

# %% [markdown]
# ### Empezamos el analisis con el primer indicador "SP.DYN.CBRT.IN".
#
# Este indicador es sobre la tasa de natalidad, bruta (por cada 1000 personas)

# %%
#Genero un nuevo df con lo que vamos a trabajar. 
df_natalidad = pd.DataFrame()
df_natalidad = df1[df1["codigo_indicador"].isin(["SP.DYN.CBRT.IN"])]
años = df_natalidad.columns[4:63]
años
df_natalidad
# Out:
#               pais codigo_pais                             indicador  \
# 20401    Argentina         ARG  Birth rate, crude (per 1,000 people)
# 28286       Brazil         BRA  Birth rate, crude (per 1,000 people)
# 32021       Canada         CAN  Birth rate, crude (per 1,000 people)
# 34096        Chile         CHL  Birth rate, crude (per 1,000 people)
# 45716       France         FRA  Birth rate, crude (per 1,000 people)
# 76011  New Zealand         NZL  Birth rate, crude (per 1,000 people)
#
#       codigo_indicador    1960    1961    1962    1963    1964    1965  ...  \
# 20401   SP.DYN.CBRT.IN  23.775  23.569  23.372  23.191  23.033  22.909  ...
# 28286   SP.DYN.CBRT.IN  42.280  41.932  41.481  40.914  40.234  39.453  ...
# 32021   SP.DYN.CBRT.IN  26.700  26.000  25.200  24.600  23.400  21.300  ...
# 34096   SP.DYN.CBRT.IN  35.556  35.108  34.588  33.994  33.332  32.614  ...
# 45716   SP.DYN.CBRT.IN  18.700  18.700  18.600  18.500  18.400  18.200  ...
# 76011   SP.DYN.CBRT.IN  26.500  27.100  26.200  25.500  24.200  22.900  ...
#
#          2011    2012    2013    2014    2015    2016    2017    2018  2019  \
# 20401  18.055  17.949  17.831  17.698  17.548  17.383  17.205  17.021   NaN
# 28286  15.110  14.930  14.772  14.624  14.472  14.307  14.125  13.924   NaN
# 32021  11.000  11.000  10.800  10.800  10.700  10.600  10.300  10.100   NaN
# 34096  14.463  14.258  14.002  13.700  13.369  13.031  12.711  12.428   NaN
# 45716  12.700  12.600  12.400  12.400  12.000  11.800  11.500  11.300   NaN
# 76011  14.000  13.870  13.200  12.680  13.270  12.650  12.430  11.980   NaN
#
#        2020
# 20401   NaN
# 28286   NaN
# 32021   NaN
# 34096   NaN
# 45716   NaN
# 76011   NaN
#
# [6 rows x 65 columns]

# %% [markdown]
# Para poder experesar los datos que tenemos sobre la tasa de natalidad, invertimos el data frame.

# %%
#Aplico el metodo melt para acomodar los columnas como corresponden
df_natalidad = pd.melt(df_natalidad, id_vars= ['pais','codigo_indicador'], value_vars = años, 
                       var_name = 'años',value_name= 'tasa_natalidad')

# %%
df_natalidad
# Out:
#             pais codigo_indicador  años  tasa_natalidad
# 0      Argentina   SP.DYN.CBRT.IN  1960          23.775
# 1         Brazil   SP.DYN.CBRT.IN  1960          42.280
# 2         Canada   SP.DYN.CBRT.IN  1960          26.700
# 3          Chile   SP.DYN.CBRT.IN  1960          35.556
# 4         France   SP.DYN.CBRT.IN  1960          18.700
# ..           ...              ...   ...             ...
# 349       Brazil   SP.DYN.CBRT.IN  2018          13.924
# 350       Canada   SP.DYN.CBRT.IN  2018          10.100
# 351        Chile   SP.DYN.CBRT.IN  2018          12.428
# 352       France   SP.DYN.CBRT.IN  2018          11.300
# 353  New Zealand   SP.DYN.CBRT.IN  2018          11.980
#
# [354 rows x 4 columns]

# %% [markdown]
# Generamos una funcion que nos permite, utilizando la biblioteca pycountry, que nos permite obtener las coordenadas geograficas de los paices con los que vamos a trabajar y luego de eso lo aplicamos a una columna de nuestro data frame.

# %%
def get_alpha_3(location):
    try:
        return pycountry.countries.get(name = location).alpha_3
    except: 
        return None
df_natalidad['coordenadas']= df_natalidad['pais'].apply(lambda x: get_alpha_3(x))
df_natalidad
# Out:
#             pais codigo_indicador  años  tasa_natalidad coordenadas
# 0      Argentina   SP.DYN.CBRT.IN  1960          23.775         ARG
# 1         Brazil   SP.DYN.CBRT.IN  1960          42.280         BRA
# 2         Canada   SP.DYN.CBRT.IN  1960          26.700         CAN
# 3          Chile   SP.DYN.CBRT.IN  1960          35.556         CHL
# 4         France   SP.DYN.CBRT.IN  1960          18.700         FRA
# ..           ...              ...   ...             ...         ...
# 349       Brazil   SP.DYN.CBRT.IN  2018          13.924         BRA
# 350       Canada   SP.DYN.CBRT.IN  2018          10.100         CAN
# 351        Chile   SP.DYN.CBRT.IN  2018          12.428         CHL
# 352       France   SP.DYN.CBRT.IN  2018          11.300         FRA
# 353  New Zealand   SP.DYN.CBRT.IN  2018          11.980         NZL
#
# [354 rows x 5 columns]

# %% [markdown]
# #### Graficos.
#
# Mostramos los graficos con la informacion del data frame de natalidad.

# %%
fig = px.line(df_natalidad,x = df_natalidad.años, y = df_natalidad.tasa_natalidad, color =df_natalidad.pais,
             title = "Tasa de natalidad.")
fig.update_xaxes(rangeslider_visible=True)
fig.show()
#plot(fig)
# Out:
# <div>                            <div id="e7435419-a776-49fa-89d8-e0b2bdb46cbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7435419-a776-49fa-89d8-e0b2bdb46cbe")) {                    Plotly.newPlot(                        "e7435419-a776-49fa-89d8-e0b2bdb46cbe",                        [{"hovertemplate":"pais=Argentina<br>a\u00f1os=%{x}<br>tasa_natalidad=%{y}<extra></extra>","legendgroup":"Argentina","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"Argentina","orientation":"v","showlegend":true,"type":"scatter","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"xaxis":"x","y":
9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e91e3e4-95d3-4a3e-94f4-64b1834b18b9")) {                    Plotly.newPlot(                        "1e91e3e4-95d3-4a3e-94f4-64b1834b18b9",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>a\u00f1os=1960<br>coordenadas=%{location}<br>tasa_natalidad=%{z}<extra></extra>","hovertext":["Argentina","Brazil","Canada","Chile","France","New Zealand"],"locations":["ARG","BRA","CAN","CHL","FRA","NZL"],"name":"","type":"choropleth","z":[23.775,42.28,26.7,35.556,18.7,26.5]}],                        {"coloraxis":{"colorbar":{"title":{"text":"tasa_natalidad"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"geo":{"center":{},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]}},"legend":{"tracegroupgap":0},"sliders":[{"active":0,"currentvalue":{"prefix":"a\u00f1os="},"len":0.9,"pad":{"b":10,"t":60},"steps":[{"args":[["1960"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1960","method":"animate"},{"args":[["1961"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1961","method":"animate"},{"args":[["1962"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1962","method":"animate"},{"args":[["1963"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1963","method":"animate"},{"args":[["1964"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1964","method":"animate"},{"args":[["1965"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1965","method":"animate"},{"args":[["1966"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1966","method":"animate"},{"args":[["1967"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1967","method":"animate"},{"args":[["1968"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1968","method":"animate"},{"args":[["1969"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1969","method":"animate"},{"args":[["1970"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1970","method":"animate"},{"args":[["1971"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1971","method":"animate"},{"args":[["1972"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1972","method":"animate"},{"args":[["1973"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1973","method":"animate"},{"args":[["1974"],{"frame":{"duration":0,"redraw":true},"fr ...

# %% [markdown]
# Lo que podemos apreciar en los graficos es lo siguiente:
# * A medida que los años pasan se puede observar que la natalidad por cada mil personas va decreciendo. En algunos casos con mas fuerza que en otros.
# * Siempre los paices latinos estuvieron por ensima de Canada, Francia y Nueva Zelanda.
# * En America en los años 60s brasil estuvo a la cabeza con la mayor taza de natalidad seguido por Chile y despues Argentina. Pero por el año 2018 se ubico primero Argentina, luego Brasil y despues Chile.

# %% [markdown]
# ## Empezamos el analisis con el segunod indicador SP.DYN.LE00.IN
#
# Este indicador se vasa en la esperanza de vida al nacer, total (años)

# %%
#Genero un nuevo df con lo que vamos a trabajar. 
df_esper_vida = pd.DataFrame()
df_esper_vida = df1[df1["codigo_indicador"].isin(["SP.DYN.LE00.IN"])]
años1 = df_esper_vida.columns[4:63]
df_esper_vida
# Out:
#               pais codigo_pais                                indicador  \
# 20483    Argentina         ARG  Life expectancy at birth, total (years)
# 28368       Brazil         BRA  Life expectancy at birth, total (years)
# 32103       Canada         CAN  Life expectancy at birth, total (years)
# 34178        Chile         CHL  Life expectancy at birth, total (years)
# 45798       France         FRA  Life expectancy at birth, total (years)
# 76093  New Zealand         NZL  Life expectancy at birth, total (years)
#
#       codigo_indicador       1960       1961       1962       1963       1964  \
# 20483   SP.DYN.LE00.IN  65.055000  65.176000  65.269000  65.348000  65.426000
# 28368   SP.DYN.LE00.IN  54.143000  54.634000  55.130000  55.627000  56.121000
# 32103   SP.DYN.LE00.IN  71.133171  71.346098  71.367073  71.380732  71.776341
# 34178   SP.DYN.LE00.IN  57.219000  57.616000  58.031000  58.467000  58.927000
# 45798   SP.DYN.LE00.IN  69.868293  70.117073  70.314634  70.514634  70.663415
# 76093   SP.DYN.LE00.IN  71.236585  70.985366  71.231707  71.280488  71.329268
#
#             1965  ...       2011       2012       2013       2014       2015  \
# 20483  65.518000  ...  75.439000  75.598000  75.756000  75.913000  76.068000
# 28368  56.610000  ...  73.921000  74.209000  74.483000  74.745000  74.994000
# 32103  71.872195  ...  81.448780  81.648780  81.748780  81.800000  81.900000
# 34178  59.415000  ...  78.986000  79.176000  79.349000  79.504000  79.646000
# 45798  70.812195  ...  82.114634  81.968293  82.219512  82.719512  82.321951
# 76093  71.226829  ...  80.904878  81.156098  81.407317  81.404878  81.456829
#
#             2016       2017       2018  2019  2020
# 20483  76.221000  76.372000  76.520000   NaN   NaN
# 28368  75.230000  75.456000  75.672000   NaN   NaN
# 32103  81.900000  81.948780  81.948780   NaN   NaN
# 34178  79.779000  79.909000  80.042000   NaN   NaN
# 45798  82.573171  82.575610  82.724390   NaN   NaN
# 76093  81.612439  81.658537  81.858537   NaN   NaN
#
# [6 rows x 65 columns]

# %%
#Aplico el metodo melt para acomodar los columnas como corresponden
df_esper_vida = pd.melt(df_esper_vida, id_vars= ['pais','codigo_indicador'], value_vars = años, 
                       var_name = 'años',value_name= 'Esperanza_vida')
df_esper_vida.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pais              354 non-null    object
#  1   codigo_indicador  354 non-null    object
#  2   años              354 non-null    object
#  3   Esperanza_vida    354 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 11.2+ KB

# %%
df_esper_vida
# Out:
#             pais codigo_indicador  años  Esperanza_vida
# 0      Argentina   SP.DYN.LE00.IN  1960       65.055000
# 1         Brazil   SP.DYN.LE00.IN  1960       54.143000
# 2         Canada   SP.DYN.LE00.IN  1960       71.133171
# 3          Chile   SP.DYN.LE00.IN  1960       57.219000
# 4         France   SP.DYN.LE00.IN  1960       69.868293
# ..           ...              ...   ...             ...
# 349       Brazil   SP.DYN.LE00.IN  2018       75.672000
# 350       Canada   SP.DYN.LE00.IN  2018       81.948780
# 351        Chile   SP.DYN.LE00.IN  2018       80.042000
# 352       France   SP.DYN.LE00.IN  2018       82.724390
# 353  New Zealand   SP.DYN.LE00.IN  2018       81.858537
#
# [354 rows x 4 columns]

# %%
def get_alpha_3(location):
    try:
        return pycountry.countries.get(name = location).alpha_3
    except: 
        return None
df_esper_vida['coordenadas']= df_esper_vida['pais'].apply(lambda x: get_alpha_3(x))
df_esper_vida
# Out:
#             pais codigo_indicador  años  Esperanza_vida coordenadas
# 0      Argentina   SP.DYN.LE00.IN  1960       65.055000         ARG
# 1         Brazil   SP.DYN.LE00.IN  1960       54.143000         BRA
# 2         Canada   SP.DYN.LE00.IN  1960       71.133171         CAN
# 3          Chile   SP.DYN.LE00.IN  1960       57.219000         CHL
# 4         France   SP.DYN.LE00.IN  1960       69.868293         FRA
# ..           ...              ...   ...             ...         ...
# 349       Brazil   SP.DYN.LE00.IN  2018       75.672000         BRA
# 350       Canada   SP.DYN.LE00.IN  2018       81.948780         CAN
# 351        Chile   SP.DYN.LE00.IN  2018       80.042000         CHL
# 352       France   SP.DYN.LE00.IN  2018       82.724390         FRA
# 353  New Zealand   SP.DYN.LE00.IN  2018       81.858537         NZL
#
# [354 rows x 5 columns]

# %%
fig = px.line(df_esper_vida,x = df_esper_vida.años, y = df_esper_vida.Esperanza_vida, color =df_esper_vida.pais,
             title = "Taza de esperanza de vida.")
fig.update_xaxes(rangeslider_visible=True)
fig.show()
#plot(fig)
# Out:
# <div>                            <div id="a5998b6a-4d86-4216-b61f-d2e461375a07" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a
"z":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]},{"hovertemplate":"pais=Canada<br>a\u00f1os=%{z}<br>Esperanza_vida=%{y}<extra></extra>","legendgroup":"Canada","line":{"color":"#00cc96","dash":"solid"},"mode":"lines","name":"Canada","scene":"scene","showlegend":true,"type":"scatter3d","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994", ...

# %%
fig2 = px.choropleth(df_esper_vida, locations = 'coordenadas', color = 'Esperanza_vida', hover_name='pais',
                     animation_frame = 'años', title= 'Evolución taza de vida al nacer.')
fig2.show()
#plot(fig2)
# Out:
# <div>                            <div id="8f81e1e2-1e85-472e-98ba-8f0a0a37b191" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8f81e1e2-1e85-472e-98ba-8f0a0a37b191")) {                    Plotly.newPlot(                        "8f81e1e2-1e85-472e-98ba-8f0a0a37b191",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>a\u00f1os=1960<br>coordenadas=%{location}<br>Esperanza_vida=%{z}<extra></extra>","hovertext":["Argentina","Brazil","Canada","Chile","France","New Zealand"],"locations":["ARG","BRA","CAN","CHL","FRA","NZL"],"name":"","type":"choropleth","z":[65.055,54.143,71.1331707317073,57.219,69.8682926829268,71.2365853658537]}],                        {"coloraxis":{"colorbar":{"title":{"text":"Esperanza_vida"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"geo":{"center":{},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]}},"legend":{"tracegroupgap":0},"sliders":[{"active":0,"currentvalue":{"prefix":"a\u00f1os="},"len":0.9,"pad":{"b":10,"t":60},"steps":[{"args":[["1960"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1960","method":"animate"},{"args":[["1961"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1961","method":"animate"},{"args":[["1962"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1962","method":"animate"},{"args":[["1963"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1963","method":"animate"},{"args":[["1964"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1964","method":"animate"},{"args":[["1965"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1965","method":"animate"},{"args":[["1966"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1966","method":"animate"},{"args":[["1967"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1967","method":"animate"},{"args":[["1968"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1968","method":"animate"},{"args":[["1969"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1969","method":"animate"},{"args":[["1970"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1970","method":"animate"},{"args":[["1971"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1971","method":"animate"},{"args":[["1972"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1972","method":"animate"},{"args":[["1973"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1973","method":"animate"},{"args":[["1974"],{"fr ...

# %% [markdown]
# #### Conclucion de lo analizado en los graficos:
# * Podemos aprecias que la esperanza de vida en todos los paises a medida que pasa el tiempo va incrementando, esto puede ser por:
#     * Mejora en el sistema sanitario.
#     * Avance en la tecnologia:
#         * En el area de saludo.
#         * En el area de produccion de alimentos.
#         * Y tambien en la creacion de comodidades para las personas.
# * Por otro lado, lo que notamos tambien es que las personas de latam, siempre tuvieron una esperanza de vida menor que las personas de Canada, Francia y Nueva Zelanda. Esto puede ser por:
#     * Los puntos nombrados anterioremente.
#     * Aparte por la cultura que maneja cada pais.
# * Veamos el caso de Argentina, Brasil y Chile.
#     * 1960: Argentina comienza liderando con 65 años, es seguida de Chile con 57 años y luego Brasil con 54 años.
#     * A medida que el tiempo va transcurriendo al llegar al Año 2018, Chile queda 1ro con 80 años, 2do Argentina con 76 años y en 3er luegar Brasil con 75 años.
#     * Lo que podemos deducir de esto es que Chile tuvo un mayor crecimiento en el sistema sanitario y en las politas de salud, en cambio los otros dos paises, no realizaron la inversion correspondiente para estar al alcance de tanto de Chile como de los otros paises a los cuales estuvimos estudiando.

# %% [markdown]
# ## Ahora vamos a trabajar con el tercer indicador HD.HCI.OVRL
# Este indicador informa el Índice de capital humano (HCI) (escala 0-1)

# %%
#Genero un nuevo df con lo que vamos a trabajar. 
df_cap_hum = pd.DataFrame()
df_cap_hum = df1[df1["codigo_indicador"].isin(["HD.HCI.OVRL"])]
años2 = df_cap_hum.columns[4:]
df_cap_hum
# Out:
#               pais codigo_pais                              indicador  \
# 20455    Argentina         ARG  Human capital index (HCI) (scale 0-1)
# 28340       Brazil         BRA  Human capital index (HCI) (scale 0-1)
# 32075       Canada         CAN  Human capital index (HCI) (scale 0-1)
# 34150        Chile         CHL  Human capital index (HCI) (scale 0-1)
# 45770       France         FRA  Human capital index (HCI) (scale 0-1)
# 76065  New Zealand         NZL  Human capital index (HCI) (scale 0-1)
#
#       codigo_indicador  1960  1961  1962  1963  1964  1965  ...  2011  2012  \
# 20455      HD.HCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
# 28340      HD.HCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
# 32075      HD.HCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
# 34150      HD.HCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
# 45770      HD.HCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
# 76065      HD.HCI.OVRL   NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN
#
#        2013  2014  2015  2016   2017      2018  2019      2020
# 20455   NaN   NaN   NaN   NaN  0.611  0.617367   NaN  0.602145
# 28340   NaN   NaN   NaN   NaN  0.560  0.545724   NaN  0.551498
# 32075   NaN   NaN   NaN   NaN  0.799  0.800090   NaN  0.797520
# 34150   NaN   NaN   NaN   NaN  0.674  0.665265   NaN  0.651604
# 45770   NaN   NaN   NaN   NaN  0.765  0.755960   NaN  0.762737
# 76065   NaN   NaN   NaN   NaN  0.767  0.771214   NaN  0.775932
#
# [6 rows x 65 columns]

# %%
#Aplico el metodo melt para acomodar los columnas como corresponden
df_cap_hum = pd.melt(df_cap_hum, id_vars= ['pais','codigo_indicador'], value_vars = años, 
                       var_name = 'años',value_name= 'capital_humano')
df_cap_hum
# Out:
#             pais codigo_indicador  años  capital_humano
# 0      Argentina      HD.HCI.OVRL  1960             NaN
# 1         Brazil      HD.HCI.OVRL  1960             NaN
# 2         Canada      HD.HCI.OVRL  1960             NaN
# 3          Chile      HD.HCI.OVRL  1960             NaN
# 4         France      HD.HCI.OVRL  1960             NaN
# ..           ...              ...   ...             ...
# 349       Brazil      HD.HCI.OVRL  2018        0.545724
# 350       Canada      HD.HCI.OVRL  2018        0.800090
# 351        Chile      HD.HCI.OVRL  2018        0.665265
# 352       France      HD.HCI.OVRL  2018        0.755960
# 353  New Zealand      HD.HCI.OVRL  2018        0.771214
#
# [354 rows x 4 columns]

# %%
df_cap_hum.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pais              354 non-null    object
#  1   codigo_indicador  354 non-null    object
#  2   años              354 non-null    object
#  3   capital_humano    18 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 11.2+ KB

# %% [markdown]
# Como podemos observar este indice tiene muy pocos datos para poder sacar una observacion.
#
# Lo que podemos interpretar es que en estos paises no se le dio mucha importancia de saber esta informacion.

# %%
def get_alpha_3(location):
    try:
        return pycountry.countries.get(name = location).alpha_3
    except: 
        return None
df_cap_hum['coordenadas']= df_cap_hum['pais'].apply(lambda x: get_alpha_3(x))
df_cap_hum
# Out:
#             pais codigo_indicador  años  capital_humano coordenadas
# 0      Argentina      HD.HCI.OVRL  1960             NaN         ARG
# 1         Brazil      HD.HCI.OVRL  1960             NaN         BRA
# 2         Canada      HD.HCI.OVRL  1960             NaN         CAN
# 3          Chile      HD.HCI.OVRL  1960             NaN         CHL
# 4         France      HD.HCI.OVRL  1960             NaN         FRA
# ..           ...              ...   ...             ...         ...
# 349       Brazil      HD.HCI.OVRL  2018        0.545724         BRA
# 350       Canada      HD.HCI.OVRL  2018        0.800090         CAN
# 351        Chile      HD.HCI.OVRL  2018        0.665265         CHL
# 352       France      HD.HCI.OVRL  2018        0.755960         FRA
# 353  New Zealand      HD.HCI.OVRL  2018        0.771214         NZL
#
# [354 rows x 5 columns]

# %%
fig2 = px.choropleth(df_cap_hum, locations = 'coordenadas', color = 'capital_humano', hover_name='pais',
                     animation_frame = 'años', title= 'Evolución taza de vida al nacer.')
fig2.show()
#plot(fig2)
# Out:
# <div>                            <div id="7c04aa45-f892-4cde-be31-ad1b8d134bb8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c04aa45-f892-4cde-be31-ad1b8d134bb8")) {                    Plotly.newPlot(                        "7c04aa45-f892-4cde-be31-ad1b8d134bb8",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>a\u00f1os=1960<br>coordenadas=%{location}<br>capital_humano=%{z}<extra></extra>","hovertext":["Argentina","Brazil","Canada","Chile","France","New Zealand"],"locations":["ARG","BRA","CAN","CHL","FRA","NZL"],"name":"","type":"choropleth","z":[null,null,null,null,null,null]}],                        {"coloraxis":{"colorbar":{"title":{"text":"capital_humano"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"geo":{"center":{},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]}},"legend":{"tracegroupgap":0},"sliders":[{"active":0,"currentvalue":{"prefix":"a\u00f1os="},"len":0.9,"pad":{"b":10,"t":60},"steps":[{"args":[["1960"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1960","method":"animate"},{"args":[["1961"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1961","method":"animate"},{"args":[["1962"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1962","method":"animate"},{"args":[["1963"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1963","method":"animate"},{"args":[["1964"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1964","method":"animate"},{"args":[["1965"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1965","method":"animate"},{"args":[["1966"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1966","method":"animate"},{"args":[["1967"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1967","method":"animate"},{"args":[["1968"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1968","method":"animate"},{"args":[["1969"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1969","method":"animate"},{"args":[["1970"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1970","method":"animate"},{"args":[["1971"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1971","method":"animate"},{"args":[["1972"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1972","method":"animate"},{"args":[["1973"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1973","method":"animate"},{"args":[["1974"],{"frame":{"duration":0,"redraw":true},"fromcur ...

# %%
fig = px.line(df_cap_hum,x = df_cap_hum.años, y = df_cap_hum.capital_humano, color =df_cap_hum.pais,
             title = "Capital humano")
fig.update_xaxes(rangeslider_visible=True)
fig.show()
#plot(fig)
# Out:
# <div>                            <div id="4b684428-7867-47ca-b5fc-49f91b738177" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b684428-7867-47ca-b5fc-49f91b738177")) {                    Plotly.newPlot(                        "4b684428-7867-47ca-b5fc-49f91b738177",                        [{"hovertemplate":"pais=Argentina<br>a\u00f1os=%{x}<br>capital_humano=%{y}<extra></extra>","legendgroup":"Argentina","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"Argentina","orientation":"v","showlegend":true,"type":"scatter","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"xaxis":"x","y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.588557064533234,null,null,null,null,null,null,0.611,0.61736673116684],"yaxis":"y"},{"hovertemplate":"pais=Brazil<br>a\u00f1os=%{x}<br>capital_humano=%{y}<extra></extra>","legendgroup":"Brazil","line":{"color":"#EF553B","dash":"solid"},"mode":"lines","name":"Brazil","orientation":"v","showlegend":true,"type":"scatter","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"xaxis":"x","y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.532952487468719,null,null,null,null,null,null,0.56,0.545723736286163],"yaxis":"y"},{"hovertemplate":"pais=Canada<br>a\u00f1os=%{x}<br>capital_humano=%{y}<extra></extra>","legendgroup":"Canada","line":{"color":"#00cc96","dash":"solid"},"mode":"lines","name":"Canada","orientation":"v","showlegend":true,"type":"scatter","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"xaxis":"x","y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.774103760719299,null,null,null,null,null,null,0.799,0.800089955329895],"yaxis":"y"},{"hovertemplate":"pais=Chile<br>a\u00f1os=%{x}<br>capital_humano=%{y}<extra></extra>","legendgroup":"Chile","line":{"color":"#ab63fa","dash":"solid"},"mode":"lines","name":"Chile","orientation":"v","showlegend":true,"type":"scatter","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","198 ...

# %%
fig0 = px.line_3d(df_cap_hum,x = df_cap_hum.años, y = df_cap_hum.capital_humano,z=df_natalidad.años,  
                  color =df_cap_hum.pais,
             title = "Capital humano.")
fig0.show()
#plot(fig0)
# Out:
# <div>                            <div id="6f6f5370-2454-454a-ad40-f5ff74684cf9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f6f5370-2454-454a-ad40-f5ff74684cf9")) {                    Plotly.newPlot(                        "6f6f5370-2454-454a-ad40-f5ff74684cf9",                        [{"hovertemplate":"pais=Argentina<br>a\u00f1os=%{x}<br>capital_humano=%{y}<br>z=%{z}<extra></extra>","legendgroup":"Argentina","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"Argentina","scene":"scene","showlegend":true,"type":"scatter3d","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.588557064533234,null,null,null,null,null,null,0.611,0.61736673116684],"z":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]},{"hovertemplate":"pais=Brazil<br>a\u00f1os=%{x}<br>capital_humano=%{y}<br>z=%{z}<extra></extra>","legendgroup":"Brazil","line":{"color":"#EF553B","dash":"solid"},"mode":"lines","name":"Brazil","scene":"scene","showlegend":true,"type":"scatter3d","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"y":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,0.532952487468719,null,null,null,null,null,null,0.56,0.545723736286163],"z":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"]},{"hovertemplate":"pais=Canada<br>a\u00f1os=%{x}<br>capital_humano=%{y}<br>z=%{z}<extra></extra>","legendgroup":"Canada","line":{"color":"#00cc96","dash":"solid"},"mode":"lines","name":"Canada","scene":"scene","showlegend":true,"type":"scatter3d","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014", ...

# %% [markdown]
# ## Trabajamos con el ultimo indicador NY.GNP.PCAP.CD
#
# El siguiente indicador es INB per cápita, método Atlas (US $ a precios actuales)

# %%
#Genero un nuevo df con lo que vamos a trabajar. 
df_inb = pd.DataFrame()
df_inb = df1[df1["codigo_indicador"].isin(["NY.GNP.PCAP.CD"])]
años3 = df_inb.columns[4:]
df_inb
# Out:
#               pais codigo_pais                                   indicador  \
# 20453    Argentina         ARG  GNI per capita, Atlas method (current US$)
# 28338       Brazil         BRA  GNI per capita, Atlas method (current US$)
# 32073       Canada         CAN  GNI per capita, Atlas method (current US$)
# 34148        Chile         CHL  GNI per capita, Atlas method (current US$)
# 45768       France         FRA  GNI per capita, Atlas method (current US$)
# 76063  New Zealand         NZL  GNI per capita, Atlas method (current US$)
#
#       codigo_indicador  1960  1961    1962    1963    1964    1965  ...  \
# 20453   NY.GNP.PCAP.CD   NaN   NaN     NaN     NaN  1120.0  1230.0  ...
# 28338   NY.GNP.PCAP.CD   NaN   NaN     NaN     NaN     NaN     NaN  ...
# 32073   NY.GNP.PCAP.CD   NaN   NaN     NaN     NaN     NaN     NaN  ...
# 34148   NY.GNP.PCAP.CD   NaN   NaN   580.0   630.0   670.0   670.0  ...
# 45768   NY.GNP.PCAP.CD   NaN   NaN  1550.0  1700.0  1870.0  2030.0  ...
# 76063   NY.GNP.PCAP.CD   NaN   NaN     NaN     NaN     NaN     NaN  ...
#
#           2011     2012     2013     2014     2015     2016     2017     2018  \
# 20453  10710.0  11870.0  12840.0  12330.0  12570.0  12220.0  13120.0  12390.0
# 28338  11080.0  12310.0  12790.0  12120.0  10190.0   8920.0   8700.0   9080.0
# 32073  47180.0  51000.0  52770.0  52180.0  47570.0  43870.0  42990.0  45000.0
# 34148  12340.0  14350.0  15160.0  14940.0  14130.0  13370.0  13270.0  14620.0
# 45768  44350.0  43380.0  43780.0  43320.0  41100.0  39070.0  38340.0  41080.0
# 76063  32270.0  36730.0  39910.0  41630.0  40560.0  39390.0  38170.0  41100.0
#
#           2019  2020
# 20453  11200.0   NaN
# 28338   9130.0   NaN
# 32073  46370.0   NaN
# 34148  15010.0   NaN
# 45768  42400.0   NaN
# 76063  42670.0   NaN
#
# [6 rows x 65 columns]

# %%
#Aplico el metodo melt para acomodar los columnas como corresponden
df_inb = pd.melt(df_inb, id_vars= ['pais','codigo_indicador'], value_vars = años, 
                       var_name = 'años',value_name= 'INB')
df_inb
# Out:
#             pais codigo_indicador  años      INB
# 0      Argentina   NY.GNP.PCAP.CD  1960      NaN
# 1         Brazil   NY.GNP.PCAP.CD  1960      NaN
# 2         Canada   NY.GNP.PCAP.CD  1960      NaN
# 3          Chile   NY.GNP.PCAP.CD  1960      NaN
# 4         France   NY.GNP.PCAP.CD  1960      NaN
# ..           ...              ...   ...      ...
# 349       Brazil   NY.GNP.PCAP.CD  2018   9080.0
# 350       Canada   NY.GNP.PCAP.CD  2018  45000.0
# 351        Chile   NY.GNP.PCAP.CD  2018  14620.0
# 352       France   NY.GNP.PCAP.CD  2018  41080.0
# 353  New Zealand   NY.GNP.PCAP.CD  2018  41100.0
#
# [354 rows x 4 columns]

# %%
df_inb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 354 entries, 0 to 353
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   pais              354 non-null    object
#  1   codigo_indicador  354 non-null    object
#  2   años              354 non-null    object
#  3   INB               318 non-null    float64
# dtypes: float64(1), object(3)
# memory usage: 11.2+ KB

# %%
def get_alpha_3(location):
    try:
        return pycountry.countries.get(name = location).alpha_3
    except: 
        return None
df_inb['coordenadas']= df_inb['pais'].apply(lambda x: get_alpha_3(x))
df_inb
# Out:
#             pais codigo_indicador  años      INB coordenadas
# 0      Argentina   NY.GNP.PCAP.CD  1960      NaN         ARG
# 1         Brazil   NY.GNP.PCAP.CD  1960      NaN         BRA
# 2         Canada   NY.GNP.PCAP.CD  1960      NaN         CAN
# 3          Chile   NY.GNP.PCAP.CD  1960      NaN         CHL
# 4         France   NY.GNP.PCAP.CD  1960      NaN         FRA
# ..           ...              ...   ...      ...         ...
# 349       Brazil   NY.GNP.PCAP.CD  2018   9080.0         BRA
# 350       Canada   NY.GNP.PCAP.CD  2018  45000.0         CAN
# 351        Chile   NY.GNP.PCAP.CD  2018  14620.0         CHL
# 352       France   NY.GNP.PCAP.CD  2018  41080.0         FRA
# 353  New Zealand   NY.GNP.PCAP.CD  2018  41100.0         NZL
#
# [354 rows x 5 columns]

# %%
fig2 = px.choropleth(df_inb, locations = 'coordenadas', color = 'INB', hover_name='pais',
                     animation_frame = 'años', title= 'INB')
fig2.show()
#plot(fig2)
# Out:
# <div>                            <div id="3830f0a5-e7cd-41dc-abac-77f3b9ccf3e5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3830f0a5-e7cd-41dc-abac-77f3b9ccf3e5")) {                    Plotly.newPlot(                        "3830f0a5-e7cd-41dc-abac-77f3b9ccf3e5",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"<b>%{hovertext}</b><br><br>a\u00f1os=1960<br>coordenadas=%{location}<br>INB=%{z}<extra></extra>","hovertext":["Argentina","Brazil","Canada","Chile","France","New Zealand"],"locations":["ARG","BRA","CAN","CHL","FRA","NZL"],"name":"","type":"choropleth","z":[null,null,null,null,null,null]}],                        {"coloraxis":{"colorbar":{"title":{"text":"INB"}},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]},"geo":{"center":{},"domain":{"x":[0.0,1.0],"y":[0.0,1.0]}},"legend":{"tracegroupgap":0},"sliders":[{"active":0,"currentvalue":{"prefix":"a\u00f1os="},"len":0.9,"pad":{"b":10,"t":60},"steps":[{"args":[["1960"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1960","method":"animate"},{"args":[["1961"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1961","method":"animate"},{"args":[["1962"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1962","method":"animate"},{"args":[["1963"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1963","method":"animate"},{"args":[["1964"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1964","method":"animate"},{"args":[["1965"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1965","method":"animate"},{"args":[["1966"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1966","method":"animate"},{"args":[["1967"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1967","method":"animate"},{"args":[["1968"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1968","method":"animate"},{"args":[["1969"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1969","method":"animate"},{"args":[["1970"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1970","method":"animate"},{"args":[["1971"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1971","method":"animate"},{"args":[["1972"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1972","method":"animate"},{"args":[["1973"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"immediate","transition":{"duration":0,"easing":"linear"}}],"label":"1973","method":"animate"},{"args":[["1974"],{"frame":{"duration":0,"redraw":true},"fromcurrent":true,"mode":"imm ...

# %%
fig = px.line(df_inb,x = df_inb.años, y = df_inb.INB, color =df_inb.pais,
             title = "Taza INB")
fig.update_xaxes(rangeslider_visible=True)
fig.show()
#plot(fig)
# Out:
# <div>                            <div id="e004931a-a80e-44bd-bc47-9bc933f62950" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e004931a-a80e-44bd-bc47-9bc933f62950")) {                    Plotly.newPlot(                        "e004931a-a80e-44bd-bc47-9bc933f62950",                        [{"hovertemplate":"pais=Argentina<br>a\u00f1os=%{x}<br>INB=%{y}<extra></extra>","legendgroup":"Argentina","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"Argentina","orientation":"v","showlegend":true,"type":"scatter","x":["1960","1961","1962","1963","1964","1965","1966","1967","1968","1969","1970","1971","1972","1973","1974","1975","1976","1977","1978","1979","1980","1981","1982","1983","1984","1985","1986","1987","1988","1989","1990","1991","1992","1993","1994","1995","1996","1997","1998","1999","2000","2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018"],"xaxis":"x","y":[null,null,null,null,1120.0,1230.0,1350.0,1240.0,1210.0,1300.0,1320.0,1470.0,1470.0,1820.0,2470.0,2720.0,2360.0,2220.0,2190.0,2630.0,2910.0,2820.0,2670.0,2870.0,2830.0,2700.0,3020.0,3590.0,3960.0,2930.0,3190.0,3860.0,6070.0,7120.0,7620.0,7360.0,7740.0,8150.0,8030.0,7580.0,7470.0,7000.0,4040.0,3650.0,3370.0,4260.0,5480.0,6510.0,7670.0,7790.0,9270.0,10710.0,11870.0,12840.0,12330.0,12570.0,12220.0,13120.0,12390.0],"yaxis":"y"},{"hovertemplate":"pais=Brazil<br>a\u00f1os=%